# %% [markdown]
# # 🏭 RL Scheduling - Generalized Training
#
# Randomizes **everything** each episode: products, work centers, operations, routing, POs, qty.
# Model learns general scheduling strategies, not factory-specific patterns.

# %%
# %pip install gymnasium stable-baselines3 numpy matplotlib torch --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 18.2 MB/s eta 0:00:00

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from dataclasses import dataclass, field
from typing import List, Dict, Tuple, Optional
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
@dataclass
class ShiftWindow:
    start_min: int
    end_min: int

@dataclass
class WorkCenterConfig:
    id: int
    name: str
    operation_id: int
    capacity_per_hour: float
    workers_required: int = 1
    cost_per_hour: float = 0.0
    shifts: Dict[int, List[ShiftWindow]] = field(default_factory=dict)

@dataclass
class JobTask:
    job_id: int
    task_idx: int
    operation_id: int
    setup_time: int
    quantity: int
    predecessors: List[int] = field(default_factory=list)

@dataclass
class ScheduledTask:
    job_id: int
    task_idx: int
    machine_id: int
    start: int
    end: int

# %% [markdown]
# ## Generalized Problem Generator

# %%
class GeneralizedGenerator:
    """
    Randomizes: WC count/capacity/shifts, products, routing DAGs, POs, qty.
    Creates realistic manufacturing patterns with parallel sub-assemblies.
    """
    CAPS = [3, 4, 6, 8, 10, 12, 15, 20, 30, 60, 90, 120]

    def __init__(self, seed=None):
        self.rng = np.random.RandomState(seed)

    def _random_shifts(self):
        p = self.rng.randint(0, 4)
        shifts = {}
        days = range(1, 7) if p >= 2 else range(1, 6)
        windows = [ShiftWindow(480, 960)]
        if p % 2 == 0:
            windows.append(ShiftWindow(960, 1440))
        for d in days:
            shifts[d] = list(windows)
        return shifts

    def _make_routing(self, op_pool):
        """Create a DAG: 2-4 parallel sub-assembly chains → final merge chain."""
        n_branches = self.rng.randint(2, 5)
        branch_len = [int(self.rng.randint(2, 6)) for _ in range(n_branches)]
        final_len = int(self.rng.randint(3, 9))
        total = sum(branch_len) + final_len
        if total > len(op_pool):
            total = len(op_pool)
            final_len = max(2, total - sum(branch_len))
            while sum(branch_len) + final_len > total:
                idx = self.rng.randint(0, len(branch_len))
                if branch_len[idx] > 2: branch_len[idx] -= 1

        ops = self.rng.choice(op_pool, size=min(total, len(op_pool)), replace=False).tolist()
        routing = []
        idx = 0
        branch_ends = []
        for b in range(n_branches):
            for s in range(branch_len[b]):
                if idx >= len(ops): break
                setup = int(self.rng.randint(5, 50))
                preds = [idx - 1] if s > 0 else []
                routing.append((ops[idx], setup, preds))
                idx += 1
            if idx > 0: branch_ends.append(idx - 1)

        for s in range(final_len):
            if idx >= len(ops): break
            setup = int(self.rng.randint(5, 50))
            if s == 0:
                preds = [e for e in branch_ends if e < idx]
            else:
                preds = [idx - 1]
            routing.append((ops[idx], setup, preds))
            idx += 1
        return routing

    def generate(self):
        n_wc = int(self.rng.randint(30, 61))
        work_centers = {}
        for i in range(n_wc):
            cap = float(self.rng.choice(self.CAPS))
            work_centers[i] = WorkCenterConfig(
                id=i, name=f'WC-{i:03d}', operation_id=0,
                capacity_per_hour=cap, workers_required=int(self.rng.randint(5, 12)),
                shifts=self._random_shifts()
            )

        n_ops = int(self.rng.randint(40, 100))
        op_ids = list(range(100, 100 + n_ops))
        op_to_wc = {}
        for op_id in op_ids:
            n = min(int(self.rng.randint(5, 12)), n_wc)
            op_to_wc[op_id] = self.rng.choice(n_wc, size=n, replace=False).tolist()

        n_products = int(self.rng.randint(5, 12))
        product_routings = [self._make_routing(op_ids) for _ in range(n_products)]

        n_orders = int(self.rng.randint(10, 30))
        jobs = []
        for i in range(n_orders):
            qty = int(self.rng.randint(20, 100))
            routing = product_routings[self.rng.randint(0, n_products)]
            job_tasks = []
            for t_idx, (op_id, setup, preds) in enumerate(routing):
                job_tasks.append(JobTask(
                    job_id=i, task_idx=t_idx, operation_id=op_id,
                    setup_time=setup, quantity=qty, predecessors=list(preds)
                ))
            jobs.append(job_tasks)

        return {
            'jobs': jobs, 'work_centers': work_centers, 'op_to_wc': op_to_wc,
            'holidays': set(), 'max_workers': 600, 'horizon_days': 120,
        }

# %% [markdown]
# ## Environment (Task-Only Action + Auto Fastest Machine)

# %%
class JSSPEnv(gym.Env):
    metadata = {"render_modes": ["human"]}

    def __init__(self, instance=None, generator_seed=None):
        super().__init__()
        self.generator = GeneralizedGenerator(seed=generator_seed)
        self.instance = instance
        self._setup_from_instance(instance or self.generator.generate())
        self.MAX_TASKS = 1000
        self.MAX_MACHINES = 100
        self.action_space = spaces.Discrete(self.MAX_TASKS)
        task_feat = 7; machine_feat = 4; global_feat = 3
        obs_size = self.MAX_TASKS * task_feat + self.MAX_MACHINES * machine_feat + global_feat
        self.obs_size = obs_size
        self.task_feat = task_feat
        self.machine_feat = machine_feat
        self.observation_space = spaces.Box(low=-1.0, high=1.0, shape=(obs_size,), dtype=np.float32)

    def _setup_from_instance(self, instance):
        self.jobs = instance['jobs']
        self.work_centers = instance['work_centers']
        self.op_to_wc = instance['op_to_wc']
        self.holidays = instance['holidays']
        self.horizon_days = instance['horizon_days']
        self.horizon_minutes = self.horizon_days * 1440
        self.all_tasks = []
        self.task_global_idx = {}
        for job in self.jobs:
            for task in job:
                g = len(self.all_tasks)
                self.task_global_idx[(task.job_id, task.task_idx)] = g
                self.all_tasks.append(task)
        self.n_tasks = len(self.all_tasks)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        if options and options.get('new_instance', False):
            self._setup_from_instance(self.generator.generate())
        elif self.instance is None:
            self._setup_from_instance(self.generator.generate())
        self.scheduled = [None] * self.n_tasks
        self.machine_timeline = {m: [] for m in self.work_centers}
        self.machine_available_time = {m: 0 for m in self.work_centers}
        self.n_scheduled = 0
        self.current_makespan = 0
        self.proc_times = {}
        for g_idx, task in enumerate(self.all_tasks):
            for wc_id in self.op_to_wc.get(task.operation_id, []):
                wc = self.work_centers.get(wc_id)
                if wc and wc.capacity_per_hour > 0:
                    pt = int(task.quantity * (60 / wc.capacity_per_hour))
                    self.proc_times[(g_idx, wc_id)] = task.setup_time + pt
        return self._get_obs(), {}

    def _is_holiday(self, m): return (m // 1440) in self.holidays
    def _is_in_shift(self, mid, m):
        wc = self.work_centers.get(mid)
        if not wc: return False
        for sw in wc.shifts.get(((m//1440)%7)+1, []):
            if sw.start_min <= m%1440 < sw.end_min: return True
        return False
    def _shift_end_at(self, mid, m):
        wc = self.work_centers.get(mid)
        if not wc: return -1
        d = m // 1440
        for sw in wc.shifts.get((d%7)+1, []):
            if sw.start_min <= m%1440 < sw.end_min: return d*1440+sw.end_min
        return -1
    def _next_shift_start(self, mid, m):
        wc = self.work_centers.get(mid)
        if not wc: return self.horizon_minutes
        t = m
        for _ in range(self.horizon_days*2):
            d = t // 1440
            if d*1440 >= self.horizon_minutes: return self.horizon_minutes
            for sw in sorted(wc.shifts.get((d%7)+1,[]), key=lambda s:s.start_min):
                if sw.start_min >= t%1440:
                    c = d*1440+sw.start_min
                    if not self._is_holiday(c): return c
            t = (d+1)*1440
        return self.horizon_minutes
    def _continuous_work_end(self, mid, start):
        cur = start
        for _ in range(20):
            se = self._shift_end_at(mid, cur)
            if se == -1: break
            if not self._is_holiday(se) and self._is_in_shift(mid, se): cur = se
            else: return se
        return cur

    def _get_valid_tasks(self):
        valid = {}
        for g, task in enumerate(self.all_tasks):
            if self.scheduled[g] is not None: continue
            ok = all(self.scheduled[self.task_global_idx.get((task.job_id,p),-1)] is not None
                     for p in task.predecessors if self.task_global_idx.get((task.job_id,p)) is not None)
            if not ok: continue
            ms = self.op_to_wc.get(task.operation_id, [])
            if ms: valid[g] = ms
        return valid

    def _get_earliest_start(self, gi, mid):
        task = self.all_tasks[gi]
        dur = self.proc_times.get((gi, mid), 60)
        e = 0
        for p in task.predecessors:
            pg = self.task_global_idx.get((task.job_id, p))
            if pg is not None and self.scheduled[pg]: e = max(e, self.scheduled[pg].end)
        e = max(e, self.machine_available_time.get(mid, 0))
        return self._find_slot(mid, e, dur)

    def _find_slot(self, mid, earliest, dur):
        t = earliest
        for _ in range(100000):
            if t >= self.horizon_minutes: return self.horizon_minutes
            if self._is_holiday(t): t=((t//1440)+1)*1440; continue
            if not self._is_in_shift(mid, t): t=self._next_shift_start(mid, t); continue
            if t+dur > self._continuous_work_end(mid, t):
                t = self._next_shift_start(mid, self._continuous_work_end(mid, t)); continue
            overlap = False
            for (s,e) in self.machine_timeline[mid]:
                if t < e and t+dur > s: overlap=True; t=e; break
            if not overlap: return t
        return self.horizon_minutes

    def _select_best_machine(self, gi, mids):
        best_m, best_end = None, float('inf')
        for mid in mids:
            dur = self.proc_times.get((gi, mid), 60)
            end = self._get_earliest_start(gi, mid) + dur
            if end < best_end: best_end = end; best_m = mid
        return best_m

    def _get_obs(self):
        obs = np.zeros(self.obs_size, dtype=np.float32)
        norm = max(self.horizon_minutes, 1)
        for i in range(min(self.n_tasks, self.MAX_TASKS)):
            t = self.all_tasks[i]; b = i * self.task_feat
            obs[b] = 1.0
            if self.scheduled[i]: obs[b+1] = 1.0
            n_alt = len(self.op_to_wc.get(t.operation_id, []))
            obs[b+2] = min(n_alt / 10.0, 1.0)  # flexibility
            pts = [self.proc_times.get((i,m),0) for m in self.op_to_wc.get(t.operation_id,[])]
            obs[b+3] = min((np.mean(pts) if pts else 0) / norm, 1.0)
            obs[b+4] = t.setup_time / max(norm, 1)
            obs[b+5] = min(t.quantity / 50.0, 1.0)
            np_ = len(t.predecessors)
            if np_ > 0:
                done = sum(1 for p in t.predecessors
                          if self.task_global_idx.get((t.job_id,p)) is not None
                          and self.scheduled[self.task_global_idx[(t.job_id,p)]] is not None)
                obs[b+6] = done / np_
            else: obs[b+6] = 1.0
        mb = self.MAX_TASKS * self.task_feat
        for i, mid in enumerate(sorted(self.work_centers.keys())):
            if i >= self.MAX_MACHINES: break
            b = mb + i * self.machine_feat
            obs[b] = 1.0
            obs[b+1] = min(self.machine_available_time.get(mid,0)/norm, 1.0)
            obs[b+2] = min(sum(e-s for s,e in self.machine_timeline[mid])/norm, 1.0)
            nq = sum(1 for g,tk in enumerate(self.all_tasks)
                    if not self.scheduled[g] and mid in self.op_to_wc.get(tk.operation_id,[]))
            obs[b+3] = min(nq / max(self.n_tasks,1), 1.0)
        gb = mb + self.MAX_MACHINES * self.machine_feat
        obs[gb] = self.n_scheduled / max(self.n_tasks, 1)
        obs[gb+1] = min(self.current_makespan / norm, 1.0)
        vt = self._get_valid_tasks()
        obs[gb+2] = len(vt) / max(self.n_tasks, 1)
        return obs

    def step(self, action):
        vt = self._get_valid_tasks()
        if not vt:
            return self._get_obs(), -self.current_makespan/self.horizon_minutes, True, False, {'makespan': self.current_makespan}
        task_a = action % self.MAX_TASKS
        best_task = min(vt.keys(), key=lambda t: abs(t - task_a))
        mid = self._select_best_machine(best_task, vt[best_task])
        if mid is None: return self._get_obs(), -1.0, True, False, {}
        task = self.all_tasks[best_task]
        dur = self.proc_times.get((best_task, mid), 60)
        start = self._get_earliest_start(best_task, mid)
        end = start + dur
        self.scheduled[best_task] = ScheduledTask(task.job_id, task.task_idx, mid, start, end)
        self.machine_timeline[mid].append((start, end))
        self.machine_timeline[mid].sort()
        self.machine_available_time[mid] = end
        self.n_scheduled += 1
        self.current_makespan = max(self.current_makespan, end)
        done = self.n_scheduled >= self.n_tasks
        reward = -self.current_makespan/self.horizon_minutes if done else -0.01*(end/self.horizon_minutes)
        return self._get_obs(), reward, done, False, {'makespan': self.current_makespan}

    def render(self):
        fig, ax = plt.subplots(figsize=(20, 10))
        colors = plt.cm.tab20(np.linspace(0, 1, max(len(self.jobs), 1)))
        active = sorted([m for m in self.work_centers if self.machine_timeline[m]])
        if not active: active = sorted(self.work_centers.keys())[:10]
        for y, mid in enumerate(active):
            wc = self.work_centers[mid]
            for day in range((self.current_makespan+480)//1440+1):
                for sw in wc.shifts.get((day%7)+1, []):
                    s,e = day*1440+sw.start_min, day*1440+sw.end_min
                    c = '#e8f5e9' if sw.start_min < 960 else '#fff3e0'
                    ax.barh(y, e-s, left=s, height=0.9, color=c, alpha=0.3)
        for gi, st in enumerate(self.scheduled):
            if st is None or st.machine_id not in active: continue
            y = active.index(st.machine_id)
            ax.barh(y, st.end-st.start, left=st.start, height=0.6,
                    color=colors[st.job_id%len(colors)], edgecolor='black', linewidth=0.3)
        ax.set_yticks(range(len(active)))
        ax.set_yticklabels([self.work_centers[m].name for m in active], fontsize=6)
        ax.set_title(f'Makespan: {self.current_makespan} min ({self.current_makespan/1440:.1f} days)')
        plt.tight_layout(); plt.show()

# %% [markdown]
# ## Verification

# %%
for trial in range(3):
    gen = GeneralizedGenerator(seed=trial)
    inst = gen.generate()
    n_tasks = sum(len(j) for j in inst['jobs'])
    qtys = [j[0].quantity for j in inst['jobs']]
    print(f'Trial {trial}: WCs={len(inst["work_centers"])}, Ops={len(inst["op_to_wc"])}, '
          f'POs={len(inst["jobs"])}, Tasks={n_tasks}, Qty={qtys}')

# Quick test
env = JSSPEnv(generator_seed=42)
obs, _ = env.reset()
done, steps = False, 0
while not done and steps < 500:
    obs, _, done, _, info = env.step(env.action_space.sample()); steps += 1
print(f'\nRandom: {env.n_scheduled}/{env.n_tasks} tasks, '
      f'makespan={env.current_makespan/1440:.1f} days')
# Out:
# Trial 0: WCs=42, Ops=53, POs=14, Tasks=232, Qty=[24, 99, 41, 30, 22, 81, 52, 43, 21, 28, 20, 46, 72, 42]
# Trial 1: WCs=35, Ops=53, POs=17, Tasks=332, Qty=[72, 41, 99, 87, 92, 96, 78, 78, 83, 57, 43, 20, 42, 79, 22, 23, 34]
# Trial 2: WCs=38, Ops=80, POs=19, Tasks=278, Qty=[36, 49, 41, 93, 66, 48, 93, 28, 99, 77, 27, 58, 67, 31, 29, 60, 28, 86, 90]
#
# Random: 276/276 tasks, makespan=7.7 days

# %% [markdown]
# ## Training

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback

env = JSSPEnv(generator_seed=42)
eval_env = JSSPEnv(generator_seed=142)

model = PPO(
    "MlpPolicy", env,
    learning_rate=3e-4, n_steps=8192, batch_size=512,
    n_epochs=20, gamma=0.995, verbose=1, seed=42,
    policy_kwargs=dict(net_arch=dict(pi=[512, 512, 256], vf=[512, 512, 256])),
)

eval_cb = EvalCallback(eval_env, best_model_save_path='./best_model/',
                       log_path='./logs/', eval_freq=50000, n_eval_episodes=10)

model.learn(total_timesteps=500_000, callback=eval_cb, progress_bar=True)
model.save('rl_jssp_scheduler')
print('✅ Saved!')
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects
# to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Output()
# /usr/local/lib/python3.12/dist-packages/ipywidgets/widgets/widget_output.py:111: DeprecationWarning:
# Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   if ip and hasattr(ip, 'kernel') and hasattr(ip.kernel, '_parent_header'):
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | -0.234   |
# | time/              |          |
# |    fps             | 105      |
# |    iterations      | 1        |
# |    time_elapsed    | 77       |
# |    total_timesteps | 8192     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 307        |
# |    ep_rew_mean          | -0.234     |
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 2          |
# |    time_elapsed         | 159        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.09364241 |
# |    clip_fraction        | 0.653      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.71      |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.134     |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.112     |
# |    value_loss           | 0.0881     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 314        |
# |    ep_rew_mean          | -0.254     |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 3          |
# |    time_elapsed         | 243        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.13546215 |
# |    clip_fraction        | 0.738      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.32      |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.132     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.112     |
# |    value_loss           | 0.000887   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 312       |
# |    ep_rew_mean          | -0.228    |
# | time/                   |           |
# |    fps                  | 100       |
# |    iterations           | 4         |
# |    time_elapsed         | 325       |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.7290462 |
# |    clip_fraction        | 0.77      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.92     |
# |    explained_variance   | 0.939     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.153    |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -0.117    |
# |    value_loss           | 0.000633  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 304        |
# |    ep_rew_mean          | -0.193     |
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 5          |
# |    time_elapsed         | 401        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.22998157 |
# |    clip_fraction        | 0.81       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.43      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.16      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.136     |
# |    value_loss           | 0.000214   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 300       |
# |    ep_rew_mean          | -0.178    |
# | time/                   |           |
# |    fps                  | 101       |
# |    iterations           | 6         |
# |    time_elapsed         | 484       |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.6154185 |
# |    clip_fraction        | 0.793     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.7      |
# |    explained_variance   | 0.929     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.126    |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.119    |
# |    value_loss           | 0.000173  |
# ---------------------------------------
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation
# environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and
# rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=50000, episode_reward=-0.32 +/- 0.33
# Episode length: 378.50 +/- 84.84
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 378        |
# |    mean_reward          | -0.317     |
# | time/                   |            |
# |    total_timesteps      | 50000      |
# | train/                  |            |
# |    approx_kl            | 0.29982817 |
# |    clip_fraction        | 0.795      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.53      |
# |    explained_variance   | 0.894      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.113     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.106     |
# |    value_loss           | 0.00029    |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 302      |
# |    ep_rew_mean     | -0.189   |
# | time/              |          |
# |    fps             | 94       |
# |    iterations      | 7        |
# |    time_elapsed    | 605      |
# |    total_timesteps | 57344    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 305        |
# |    ep_rew_mean          | -0.191     |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 8          |
# |    time_elapsed         | 688        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.17967771 |
# |    clip_fraction        | 0.727      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.71      |
# |    explained_variance   | 0.758      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.107     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0793    |
# |    value_loss           | 0.000328   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 317        |
# |    ep_rew_mean          | -0.218     |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 9          |
# |    time_elapsed         | 773        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.30198106 |
# |    clip_fraction        | 0.775      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.88      |
# |    explained_variance   | 0.921      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.158     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.13      |
# |    value_loss           | 6.18e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 317        |
# |    ep_rew_mean          | -0.218     |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 10         |
# |    time_elapsed         | 858        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.13323972 |
# |    clip_fraction        | 0.689      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.778      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0719    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0743    |
# |    value_loss           | 0.000259   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 307        |
# |    ep_rew_mean          | -0.226     |
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 11         |
# |    time_elapsed         | 935        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.18871395 |
# |    clip_fraction        | 0.662      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.43      |
# |    explained_variance   | 0.774      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0669    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0703    |
# |    value_loss           | 0.000267   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 307        |
# |    ep_rew_mean          | -0.235     |
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 12         |
# |    time_elapsed         | 1016       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.14889546 |
# |    clip_fraction        | 0.565      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.78      |
# |    explained_variance   | 0.519      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0574    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0524    |
# |    value_loss           | 0.000192   |
# ----------------------------------------
# Eval num_timesteps=100000, episode_reward=-0.14 +/- 0.09
# Episode length: 315.90 +/- 111.11
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 316        |
# |    mean_reward          | -0.141     |
# | time/                   |            |
# |    total_timesteps      | 100000     |
# | train/                  |            |
# |    approx_kl            | 0.25972924 |
# |    clip_fraction        | 0.646      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | 0.837      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.118     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0734    |
# |    value_loss           | 4.86e-05   |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | -0.215   |
# | time/              |          |
# |    fps             | 94       |
# |    iterations      | 13       |
# |    time_elapsed    | 1130     |
# |    total_timesteps | 106496   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 310        |
# |    ep_rew_mean          | -0.225     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 14         |
# |    time_elapsed         | 1216       |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.12577876 |
# |    clip_fraction        | 0.555      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.47      |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0493    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0542    |
# |    value_loss           | 7.41e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 324        |
# |    ep_rew_mean          | -0.223     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 15         |
# |    time_elapsed         | 1302       |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.11909671 |
# |    clip_fraction        | 0.523      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.67      |
# |    explained_variance   | 0.553      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0593    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0418    |
# |    value_loss           | 0.000154   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | -0.214      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 16          |
# |    time_elapsed         | 1389        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.123398274 |
# |    clip_fraction        | 0.452       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0309     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 0.000626    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 316        |
# |    ep_rew_mean          | -0.215     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 17         |
# |    time_elapsed         | 1469       |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.24982482 |
# |    clip_fraction        | 0.544      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.29      |
# |    explained_variance   | 0.781      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0784    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0474    |
# |    value_loss           | 8.84e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 314         |
# |    ep_rew_mean          | -0.185      |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 18          |
# |    time_elapsed         | 1549        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.069560215 |
# |    clip_fraction        | 0.43        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0437     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 0.000378    |
# -----------------------------------------
# Eval num_timesteps=150000, episode_reward=-0.17 +/- 0.07
# Episode length: 318.60 +/- 99.15
# --------------------------------------
# | eval/                   |          |
# |    mean_ep_length       | 319      |
# |    mean_reward          | -0.167   |
# | time/                   |          |
# |    total_timesteps      | 150000   |
# | train/                  |          |
# |    approx_kl            | 0.221594 |
# |    clip_fraction        | 0.592    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.7     |
# |    explained_variance   | 0.679    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0716  |
# |    n_updates            | 360      |
# |    policy_gradient_loss | -0.0503  |
# |    value_loss           | 1.52e-05 |
# --------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | -0.189   |
# | time/              |          |
# |    fps             | 93       |
# |    iterations      | 19       |
# |    time_elapsed    | 1658     |
# |    total_timesteps | 155648   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 306        |
# |    ep_rew_mean          | -0.216     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 20         |
# |    time_elapsed         | 1741       |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.04640446 |
# |    clip_fraction        | 0.382      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.32      |
# |    explained_variance   | 0.75       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0471    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0348    |
# |    value_loss           | 6.1e-05    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | -0.207      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 21          |
# |    time_elapsed         | 1820        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.049594134 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.036      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 0.000304    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 313         |
# |    ep_rew_mean          | -0.201      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 22          |
# |    time_elapsed         | 1902        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.052883886 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.051      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 4.33e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 295        |
# |    ep_rew_mean          | -0.194     |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 23         |
# |    time_elapsed         | 1975       |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.12134257 |
# |    clip_fraction        | 0.409      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.523      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0193    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.018     |
# |    value_loss           | 0.000105   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | -0.181      |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 24          |
# |    time_elapsed         | 2066        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.056802344 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0328     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0242     |
# |    value_loss           | 0.000136    |
# -----------------------------------------
# Eval num_timesteps=200000, episode_reward=-0.23 +/- 0.33
# Episode length: 309.80 +/- 118.33
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 310       |
# |    mean_reward          | -0.23     |
# | time/                   |           |
# |    total_timesteps      | 200000    |
# | train/                  |           |
# |    approx_kl            | 0.1245347 |
# |    clip_fraction        | 0.35      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.71     |
# |    explained_variance   | 0.791     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0324   |
# |    n_updates            | 480       |
# |    policy_gradient_loss | -0.0216   |
# |    value_loss           | 5.17e-05  |
# ---------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | -0.224   |
# | time/              |          |
# |    fps             | 93       |
# |    iterations      | 25       |
# |    time_elapsed    | 2181     |
# |    total_timesteps | 204800   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 316        |
# |    ep_rew_mean          | -0.225     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 26         |
# |    time_elapsed         | 2262       |
# |    total_timesteps      | 212992     |
# | train/                  |            |
# |    approx_kl            | 0.05545342 |
# |    clip_fraction        | 0.346      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | 0.389      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0366    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0242    |
# |    value_loss           | 0.000223   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 331         |
# |    ep_rew_mean          | -0.212      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 27          |
# |    time_elapsed         | 2346        |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.060651615 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0234     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 3.89e-05    |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 309      |
# |    ep_rew_mean          | -0.196   |
# | time/                   |          |
# |    fps                  | 94       |
# |    iterations           | 28       |
# |    time_elapsed         | 2425     |
# |    total_timesteps      | 229376   |
# | train/                  |          |
# |    approx_kl            | 0.263844 |
# |    clip_fraction        | 0.531    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.73    |
# |    explained_variance   | 0.97     |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0717  |
# |    n_updates            | 540      |
# |    policy_gradient_loss | -0.044   |
# |    value_loss           | 7.77e-06 |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 313         |
# |    ep_rew_mean          | -0.168      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 29          |
# |    time_elapsed         | 2514        |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.050102886 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0347     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 9.19e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 314        |
# |    ep_rew_mean          | -0.171     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 30         |
# |    time_elapsed         | 2596       |
# |    total_timesteps      | 245760     |
# | train/                  |            |
# |    approx_kl            | 0.41497892 |
# |    clip_fraction        | 0.559      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0406    |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0273    |
# |    value_loss           | 7.69e-06   |
# ----------------------------------------
# Eval num_timesteps=250000, episode_reward=-0.24 +/- 0.34
# Episode length: 289.30 +/- 75.87
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 289         |
# |    mean_reward          | -0.237      |
# | time/                   |             |
# |    total_timesteps      | 250000      |
# | train/                  |             |
# |    approx_kl            | 0.050333656 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0223     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.000107    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 312      |
# |    ep_rew_mean     | -0.205   |
# | time/              |          |
# |    fps             | 94       |
# |    iterations      | 31       |
# |    time_elapsed    | 2696     |
# |    total_timesteps | 253952   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | -0.191      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 32          |
# |    time_elapsed         | 2776        |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.040818337 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0407     |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 0.000279    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 304        |
# |    ep_rew_mean          | -0.198     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 33         |
# |    time_elapsed         | 2860       |
# |    total_timesteps      | 270336     |
# | train/                  |            |
# |    approx_kl            | 0.13540101 |
# |    clip_fraction        | 0.443      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.65      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0471    |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.0303    |
# |    value_loss           | 1.21e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 307        |
# |    ep_rew_mean          | -0.194     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 34         |
# |    time_elapsed         | 2940       |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.04976383 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | 0.467      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0224    |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.0194    |
# |    value_loss           | 8.33e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 310         |
# |    ep_rew_mean          | -0.192      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 35          |
# |    time_elapsed         | 3022        |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.041131727 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0287     |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 2.39e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | -0.196      |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 36          |
# |    time_elapsed         | 3102        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.044162814 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 0.00016     |
# -----------------------------------------
# Eval num_timesteps=300000, episode_reward=-0.29 +/- 0.41
# Episode length: 326.40 +/- 80.66
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 326         |
# |    mean_reward          | -0.294      |
# | time/                   |             |
# |    total_timesteps      | 300000      |
# | train/                  |             |
# |    approx_kl            | 0.040786818 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0416     |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 6.76e-05    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | -0.193   |
# | time/              |          |
# |    fps             | 94       |
# |    iterations      | 37       |
# |    time_elapsed    | 3211     |
# |    total_timesteps | 303104   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 296         |
# |    ep_rew_mean          | -0.204      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 38          |
# |    time_elapsed         | 3289        |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.052448608 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0267     |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 4.04e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -0.183      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 39          |
# |    time_elapsed         | 3369        |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.056550294 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0226     |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 8.41e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 299         |
# |    ep_rew_mean          | -0.176      |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 40          |
# |    time_elapsed         | 3445        |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.048077997 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 0.000159    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | -0.202      |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 41          |
# |    time_elapsed         | 3527        |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.046064705 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0309     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 6.16e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 303        |
# |    ep_rew_mean          | -0.218     |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 42         |
# |    time_elapsed         | 3614       |
# |    total_timesteps      | 344064     |
# | train/                  |            |
# |    approx_kl            | 0.07057904 |
# |    clip_fraction        | 0.324      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | 0.793      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0538    |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.0322    |
# |    value_loss           | 0.000111   |
# ----------------------------------------
# Eval num_timesteps=350000, episode_reward=-0.11 +/- 0.05
# Episode length: 290.90 +/- 98.46
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 291         |
# |    mean_reward          | -0.114      |
# | time/                   |             |
# |    total_timesteps      | 350000      |
# | train/                  |             |
# |    approx_kl            | 0.037400186 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0245     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 5.62e-05    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | -0.215   |
# | time/              |          |
# |    fps             | 94       |
# |    iterations      | 43       |
# |    time_elapsed    | 3727     |
# |    total_timesteps | 352256   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 322        |
# |    ep_rew_mean          | -0.205     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 44         |
# |    time_elapsed         | 3808       |
# |    total_timesteps      | 360448     |
# | train/                  |            |
# |    approx_kl            | 0.43948802 |
# |    clip_fraction        | 0.499      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0555    |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0272    |
# |    value_loss           | 9.65e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 322        |
# |    ep_rew_mean          | -0.168     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 45         |
# |    time_elapsed         | 3888       |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.19704792 |
# |    clip_fraction        | 0.488      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0475    |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.0309    |
# |    value_loss           | 6.38e-06   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 309       |
# |    ep_rew_mean          | -0.152    |
# | time/                   |           |
# |    fps                  | 95        |
# |    iterations           | 46        |
# |    time_elapsed         | 3961      |
# |    total_timesteps      | 376832    |
# | train/                  |           |
# |    approx_kl            | 0.2660299 |
# |    clip_fraction        | 0.426     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.19     |
# |    explained_variance   | 0.94      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0612   |
# |    n_updates            | 900       |
# |    policy_gradient_loss | -0.041    |
# |    value_loss           | 1e-05     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 304        |
# |    ep_rew_mean          | -0.158     |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 47         |
# |    time_elapsed         | 4049       |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.08131601 |
# |    clip_fraction        | 0.396      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.94       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0266    |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.0356    |
# |    value_loss           | 9.9e-06    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | -0.169      |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 48          |
# |    time_elapsed         | 4133        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.052502908 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.025      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00918    |
# |    value_loss           | 0.000158    |
# -----------------------------------------
# Eval num_timesteps=400000, episode_reward=-0.14 +/- 0.12
# Episode length: 293.80 +/- 104.76
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 294         |
# |    mean_reward          | -0.138      |
# | time/                   |             |
# |    total_timesteps      | 400000      |
# | train/                  |             |
# |    approx_kl            | 0.044547793 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0332     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 5.74e-05    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 321      |
# |    ep_rew_mean     | -0.202   |
# | time/              |          |
# |    fps             | 94       |
# |    iterations      | 49       |
# |    time_elapsed    | 4245     |
# |    total_timesteps | 401408   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 328         |
# |    ep_rew_mean          | -0.223      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 50          |
# |    time_elapsed         | 4327        |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.030580081 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0244     |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.000121    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 314         |
# |    ep_rew_mean          | -0.213      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 51          |
# |    time_elapsed         | 4405        |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.029455155 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.595       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0235     |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 0.000139    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | -0.227      |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 52          |
# |    time_elapsed         | 4487        |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.045027938 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.781       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0258     |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 8.52e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | -0.202      |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 53          |
# |    time_elapsed         | 4561        |
# |    total_timesteps      | 434176      |
# | train/                  |             |
# |    approx_kl            | 0.068806365 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0305     |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 5.63e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | -0.213     |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 54         |
# |    time_elapsed         | 4644       |
# |    total_timesteps      | 442368     |
# | train/                  |            |
# |    approx_kl            | 0.07705508 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.789      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0397    |
# |    n_updates            | 1060       |
# |    policy_gradient_loss | -0.0238    |
# |    value_loss           | 0.000225   |
# ----------------------------------------
# Eval num_timesteps=450000, episode_reward=-0.17 +/- 0.09
# Episode length: 314.20 +/- 109.48
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 314         |
# |    mean_reward          | -0.169      |
# | time/                   |             |
# |    total_timesteps      | 450000      |
# | train/                  |             |
# |    approx_kl            | 0.059588887 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0295     |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 9.24e-05    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | -0.214   |
# | time/              |          |
# |    fps             | 94       |
# |    iterations      | 55       |
# |    time_elapsed    | 4754     |
# |    total_timesteps | 450560   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 303        |
# |    ep_rew_mean          | -0.197     |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 56         |
# |    time_elapsed         | 4834       |
# |    total_timesteps      | 458752     |
# | train/                  |            |
# |    approx_kl            | 0.06257713 |
# |    clip_fraction        | 0.297      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.611      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0318    |
# |    n_updates            | 1100       |
# |    policy_gradient_loss | -0.0208    |
# |    value_loss           | 0.000117   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 308       |
# |    ep_rew_mean          | -0.172    |
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 57        |
# |    time_elapsed         | 4917      |
# |    total_timesteps      | 466944    |
# | train/                  |           |
# |    approx_kl            | 0.6592977 |
# |    clip_fraction        | 0.542     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.24     |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0492   |
# |    n_updates            | 1120      |
# |    policy_gradient_loss | -0.0192   |
# |    value_loss           | 8.13e-06  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 313         |
# |    ep_rew_mean          | -0.21       |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 58          |
# |    time_elapsed         | 4998        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.053524632 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.029      |
# |    n_updates            | 1140        |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 2.64e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 312        |
# |    ep_rew_mean          | -0.184     |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 59         |
# |    time_elapsed         | 5080       |
# |    total_timesteps      | 483328     |
# | train/                  |            |
# |    approx_kl            | 0.03565024 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.582      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0245    |
# |    n_updates            | 1160       |
# |    policy_gradient_loss | -0.00223   |
# |    value_loss           | 0.000199   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 315        |
# |    ep_rew_mean          | -0.21      |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 60         |
# |    time_elapsed         | 5163       |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.45839158 |
# |    clip_fraction        | 0.512      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | 0.76       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0307    |
# |    n_updates            | 1180       |
# |    policy_gradient_loss | -0.0212    |
# |    value_loss           | 1.67e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 317        |
# |    ep_rew_mean          | -0.201     |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 61         |
# |    time_elapsed         | 5247       |
# |    total_timesteps      | 499712     |
# | train/                  |            |
# |    approx_kl            | 0.03086659 |
# |    clip_fraction        | 0.323      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.45      |
# |    explained_variance   | 0.743      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0183    |
# |    n_updates            | 1200       |
# |    policy_gradient_loss | -0.0155    |
# |    value_loss           | 0.000116   |
# ----------------------------------------
# Eval num_timesteps=500000, episode_reward=-0.25 +/- 0.35
# Episode length: 311.00 +/- 86.16
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 311        |
# |    mean_reward          | -0.254     |
# | time/                   |            |
# |    total_timesteps      | 500000     |
# | train/                  |            |
# |    approx_kl            | 0.08853029 |
# |    clip_fraction        | 0.435      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.47      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0585    |
# |    n_updates            | 1220       |
# |    policy_gradient_loss | -0.0272    |
# |    value_loss           | 1.11e-05   |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 316      |
# |    ep_rew_mean     | -0.217   |
# | time/              |          |
# |    fps             | 94       |
# |    iterations      | 62       |
# |    time_elapsed    | 5353     |
# |    total_timesteps | 507904   |
# ---------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✅ Saved!

# %% [markdown]
# ## Evaluate & Compare

# %%
n_test = 5
rl_ms, rand_ms = [], []
for i in range(n_test):
    test_env = JSSPEnv(generator_seed=1000+i)
    obs, _ = test_env.reset()
    done = False
    while not done:
        a, _ = model.predict(obs, deterministic=True)
        obs, _, done, _, _ = test_env.step(a)
    rl_ms.append(test_env.current_makespan)

    obs, _ = test_env.reset()
    done = False
    while not done:
        obs, _, done, _, _ = test_env.step(test_env.action_space.sample())
    rand_ms.append(test_env.current_makespan)

print(f'RL vs Random ({n_test} instances):')
for i in range(n_test):
    imp = (rand_ms[i]-rl_ms[i])/rand_ms[i]*100
    print(f'  #{i+1}: RL={rl_ms[i]/1440:.1f}d, Rand={rand_ms[i]/1440:.1f}d, Imp={imp:.1f}%')
print(f'Avg: RL={np.mean(rl_ms)/1440:.1f}d, Rand={np.mean(rand_ms)/1440:.1f}d, '
      f'Imp={(np.mean(rand_ms)-np.mean(rl_ms))/np.mean(rand_ms)*100:.1f}%')

# Show last schedule
test_env.render()
# Out:
# RL vs Random (5 instances):
#   #1: RL=8.4d, Rand=7.5d, Imp=-11.7%
#   #2: RL=3.4d, Rand=9.9d, Imp=65.8%
#   #3: RL=3.7d, Rand=16.4d, Imp=77.7%
#   #4: RL=12.4d, Rand=3.4d, Imp=-269.0%
#   #5: RL=3.6d, Rand=7.6d, Imp=51.8%
# Avg: RL=6.3d, Rand=8.9d, Imp=29.5%
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
